# %% [markdown]
# ## Study of coverage
# The goal of this file is to find why some references are missing from some sources.

# %%
import pandas as pd
import numpy as np
from itertools import product
import random
import matplotlib.pyplot as plt
import random
import seaborn as sns

#Create color for bar chart belows
def create_colors(nb_color):
    random.seed(190700)
    color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(nb_color)]
    return color

# Function to create the column with the information of combination of source that return a paper
def compute_combination(row):
    combination = np.array([row[i] for i in range(df.shape[1]-3)])
    return possibleCombination_code[str(combination)]

# Function to transform every possible source from IEEE that have different names (e.g IEEE Transactions on Medical Imaging) into IEEE
def process_venue(row):
    if "IEEE" in row["venue"]:
        return "IEEE"
    else:
        return row["venue"]

#Load csv and drop entry with venue not known
df = pd.read_csv("../../results/processed_csv/coverage.csv",index_col=0)
df = df.dropna(subset=["venue"])

#Compute every possible combination of True and False for the number of sources we use
possibleCombination = sorted(np.array([ele for ele in product([True,False], repeat = df.shape[1]-3)]),key=sum)
#Attribute a id to this combination
possibleCombination_code = {str(e):i for i,e in enumerate(possibleCombination)}

df["combination"] =df.apply(compute_combination,axis=1)
df["venue"] = df.apply(process_venue,axis=1)

#Sort value by combination to have easier navigation/research in the html
df = df.sort_values('combination',ascending=False)

#Use to color the html cells to green if the paper is returned by a source and red otherwise
def color_background(row):
    return [
        'background-color: green; color: green' if cell == True
        else 'background-color: red; color: red'
        for cell in row
    ]
#Applied the function to the sources columns only
df_html = df.iloc[:,:df.shape[1]-1].style.apply(color_background,subset=df.columns[0:-4])
#Export to HTML
df_html.to_html("../../results/other/coverage.html")

# %% [markdown]
# ### Combinations code

# %%
print(list(df.columns[0:-4]))
possibleCombination_code
# Out:
# ['poci', 'openalex', 'coci']
# {'[False False False]': 0,
#  '[ True False False]': 1,
#  '[False  True False]': 2,
#  '[False False  True]': 3,
#  '[ True  True False]': 4,
#  '[ True False  True]': 5,
#  '[False  True  True]': 6,
#  '[ True  True  True]': 7}

# %% [markdown]
# ## By venue

# %%
number_of_colors = 6
color = create_colors(number_of_colors)

max_number_venue = 10
df_plot = df[df['venue'].isin(df['venue'].value_counts()[:max_number_venue].index.tolist())]
df_plot = df_plot.astype({"venue": str, "combination": int})
plt.figure(figsize=(15,5))

((df_plot.groupby(['venue','combination'])["poci"].count()/df_plot.groupby(['venue'])["poci"].count()).unstack(fill_value=0).stack()).plot.bar(color=color)
plt.title("Count of combinations by venue")
# Out:
# Text(0.5, 1.0, 'Count of combinations by venue')

# %%
#Compute statistics when the combination is 3 (i.e when OpenCitation with Crossref return the paper but not OpenAlex)
comb3_percentage = (df[df["combination"] == 3].groupby('venue').count()["poci"]/df.groupby('venue')["poci"].count()*100)
comb3_count = df[df["combination"] == 3].groupby('venue').count()["poci"]
venue_count = df.groupby('venue').count()["poci"]

comb3_mix = pd.concat([comb3_count,venue_count,comb3_percentage],axis=1)
comb3_mix.columns = ["comb3 count","venue count","%"]
comb3_mix = comb3_mix.dropna(subset="%").sort_values("%",ascending=False)
comb3_mix
# Out:
#                                                     comb3 count  venue count  \
# venue
# Pure Mathematics                                            1.0            1
# Open Access Macedonian Journal of Medical Sciences          1.0            1
# Medical Imaging 2022: Biomedical Applications i...          2.0            2
# International Conference on Telecommunications              1.0            1
# International Conference on Machine Learning an...          1.0            1
# International Conference on Consumer Electronics            1.0            1
# International Conference on Bioinformatics                  1.0            1
# 2021 10th International Conference on System Mo...          1.0            1
# International Conference Bioscience, Biochemist...          1.0            1
# Medical Imaging 2022: Image Perception, Observe...          1.0            1
# Medical Imaging 2022: Imaging Informatics for H...          1.0            1
# Medical Imaging 2022: Physics of Medical Imaging            1.0            1
# Nature Methods                                              1.0            1
# Chinese Physics                                             1.0            1
# Chinese Control and Decision Conference                     1.0            1
# Journal of Medical Imaging and Health Informatics           3.0            3
# 2021 10th International Conference on System Mo...          1.0            1
# Second IYSF Academic Symposium on Artificial In...          1.0            1
# 2022 International Conference on Sustainable Co...          1.0            1
# 2022 International Conference on Machine Vision...          1.0            1
# 2022 International Conference for Advancement i...          1.0            1
# 2022 9th International Conference on Computing ...          1.0            1
# 2022 2nd International Conference on Artificial...          1.0            1
# Biomedical Engineering: Applications, Basis and...          1.0            1
# 2021 Smart Technologies, Communication and Robo...          1.0            1
# 2021 5th International Conference on Trends in ...          1.0            1
# 2021 3rd International Conference on Advances i...          1.0            1
# 2021 3rd International Academic Exchange Confer...          1.0            1
# 2021 36th International Conference on Image and...          1.0            1
# 2021 15th International Conference on Open Sour...          1.0            1
# Medical Imaging 2022: Computer-Aided Diagnosis              3.0            4
# International Parallel and Distributed Processi...          1.0            2
# 2018 2nd International Conference on Electronic...          1.0            2
# medRxiv                                                     1.0            2
# Annual review of biomedical data science                    1.0            2
# International Journal of Image and Graphics                 1.0            2
# International Conference on Advanced Technologi...          2.0            6
# Systems, Man and Cybernetics                                1.0            3
# Medical Imaging 2022: Image Processing                      1.0            3
# Current Medical Imaging Reviews                             2.0            6
# Chinese Control Conference                                  1.0            3
# British Journal of Radiology                                1.0            3
# Diagnostic and interventional imaging                       1.0            5
# IEEE                                                       33.0          394
# Electronics                                                 1.0           13
# HAL (Le Centre pour la Communication Scientifiq...          1.0           17
# International Journal of Computer Assisted Radi...          1.0           22
# Scientific Reports                                          2.0           53
# Medical Physics                                             2.0           66
# Springer International Publishing eBooks                    2.0           87
# International Symposium on Biomedical Imaging               1.0           45
# Lecture Notes in Computer Science                           6.0          508
# arXiv (Cornell University)                                  1.0          156
#
#                                                              %
# venue
# Pure Mathematics                                    100.000000
# Open Access Macedonian Journal of Medical Sciences  100.000000
# Medical Imaging 2022: Biomedical Applications i...  100.000000
# International Conference on Telecommunications      100.000000
# International Conference on Machine Learning an...  100.000000
# International Conference on Consumer Electronics    100.000000
# International Conference on Bioinformatics          100.000000
# 2021 10th International Conference on System Mo...  100.000000
# International Conference Bioscience, Biochemist...  100.000000
# Medical Imaging 2022: Image Perception, Observe...  100.000000
# Medical Imaging 2022: Imaging Informatics for H...  100.000000
# Medical Imaging 2022: Physics of Medical Imaging    100.000000
# Nature Methods                                      100.000000
# Chinese Physics                                     100.000000
# Chinese Control and Decision Conference             100.000000
# Journal of Medical Imaging and Health Informatics   100.000000
# 2021 10th International Conference on System Mo...  100.000000
# Second IYSF Academic Symposium on Artificial In...  100.000000
# 2022 International Conference on Sustainable Co...  100.000000
# 2022 International Conference on Machine Vision...  100.000000
# 2022 International Conference for Advancement i...  100.000000
# 2022 9th International Conference on Computing ...  100.000000
# 2022 2nd International Conference on Artificial...  100.000000
# Biomedical Engineering: Applications, Basis and...  100.000000
# 2021 Smart Technologies, Communication and Robo...  100.000000
# 2021 5th International Conference on Trends in ...  100.000000
# 2021 3rd International Conference on Advances i...  100.000000
# 2021 3rd International Academic Exchange Confer...  100.000000
# 2021 36th International Conference on Image and...  100.000000
# 2021 15th International Conference on Open Sour...  100.000000
# Medical Imaging 2022: Computer-Aided Diagnosis       75.000000
# International Parallel and Distributed Processi...   50.000000
# 2018 2nd International Conference on Electronic...   50.000000
# medRxiv                                              50.000000
# Annual review of biomedical data science             50.000000
# International Journal of Image and Graphics          50.000000
# International Conference on Advanced Technologi...   33.333333
# Systems, Man and Cybernetics                         33.333333
# Medical Imaging 2022: Image Processing               33.333333
# Current Medical Imaging Reviews                      33.333333
# Chinese Control Conference                           33.333333
# British Journal of Radiology                         33.333333
# Diagnostic and interventional imaging                20.000000
# IEEE                                                  8.375635
# Electronics                                           7.692308
# HAL (Le Centre pour la Communication Scientifiq...    5.882353
# International Journal of Computer Assisted Radi...    4.545455
# Scientific Reports                                    3.773585
# Medical Physics                                       3.030303
# Springer International Publishing eBooks              2.298851
# International Symposium on Biomedical Imaging         2.222222
# Lecture Notes in Computer Science                     1.181102
# arXiv (Cornell University)                            0.641026

# %% [markdown]
# Check for IEEE which seems problematic

# %%
number_of_colors = 5
color = create_colors(number_of_colors)
plt.figure()
plt.title("Histogram of combination for IEEE venue")
df_plot[df_plot["venue"]=="IEEE"].groupby(['combination'])["poci"].count().plot.bar(color=color)
# Out:
# <AxesSubplot: title={'center': 'Histogram of combination for IEEE venue'}, xlabel='combination'>

# %% [markdown]
# ## By year

# %%
number_of_colors = 7
color = create_colors(number_of_colors)

df_plot = df[df["publication_year"] == df["publication_year"]]
df_plot = df.astype({"publication_year": str, "combination": int})
plt.figure(figsize=(15,5))

((df_plot.groupby(['publication_year','combination'])["poci"].count()/df_plot.groupby(['publication_year'])["poci"].count()).unstack(fill_value=0).stack()).plot.bar(color=color)
plt.title("Count of combinations by year")
# Out:
# Text(0.5, 1.0, 'Count of combinations by year')

# %% [markdown]
# ## By open access

# %%
number_of_colors = 7
color = create_colors(number_of_colors)

((df.groupby(['is_oa','combination'])["poci"].count()/df_plot.groupby(['is_oa'])["poci"].count()).unstack(fill_value=0).stack()).plot.bar(color=color)
plt.title("Count of combinations with open access status")
# Out:
# Text(0.5, 1.0, 'Count of combinations with open access status')

# %% [markdown]
# # Comparaison of sources

# %%
dict_compare = {source1:{source2:None for source2 in df.columns[0:-4]} for source1 in df.columns[0:-4]}

#With pie chart
i = 0
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(12, 8),facecolor='#eadcdc')
plt.suptitle(r"% of shared paper between sources")
for source1 in df.columns[0:-4]:
    for source2 in df.columns[0:-4]:
        i+=1
        plt.subplot(3,3,i)
        if source1 == source2:
            plt.pie([0],labels=[''],normalize=False,startangle=90,colors=["orange"])
            continue
        shared_coverage = df[(df[source1] == True) & (df[source2] == True)]
        val = len(shared_coverage)/len(df[df[source1]==True])
        dict_compare[source1][source2] = val*100
        plt.pie([val],labels=[''],normalize=False,startangle=90,autopct=lambda p:f"{round(p)}%",colors=["#ffa100"],pctdistance=0)

for ax, col in zip(axes[0], df.columns[0:-4]):
    ax.set_title(col)

for ax, row in zip(axes[:,0], df.columns[0:-4]):
    ax.set_ylabel(row, rotation=0, size='large',labelpad=15)
    
plt.show()


#With heatmap
df_compare = pd.DataFrame.from_dict(dict_compare)
plt.figure(figsize=(12, 8))
plt.title(r"% of shared papers between sources")
sns.heatmap(df_compare.T, annot=True,cmap="crest")
sns.set_context("notebook")

# %% [markdown]
# ## Number of citation for ACDC

# %%
df_acdc = df[df["dataset_used"] == "ACDC"]

plt.figure()
ax = df_acdc.groupby(["publication_year"]).count()["dataset_used"].plot(style='-o')
for y in df_acdc.groupby(["publication_year"]).count().iterrows(): 
    ax.annotate(y[1][0],(y[0]+0.1, y[1][0]-6))
plt.title("Number of papers citing ACDC per year")
plt.ylabel("Number of citations")
plt.xlabel("Year")
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/theo/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Number of citation by dataset

# %%
df = pd.read_csv("../../results/extracted_csv/paper_openalex.csv")
ax = df.groupby(["dataset_used","publication_year"]).count().unstack().reset_index()
columns = ax["dataset_used"]
ax = ax["name"].T
ax.columns = columns
ax = ax.replace(np.nan,0)
plt.figure()
ax.plot(style='o-')
plt.title("Number of references per year using OpenAlex for selected datasets")
# Out:
# Text(0.5, 1.0, 'Number of references per year using OpenAlex for selected datasets')

# %%
df = pd.read_csv("../../data/abstract_dataset_clean2.csv")
ax = df.groupby(["task","publication_year"]).count().unstack().reset_index()
columns = ax["task"]
ax = ax["abstract"].T
ax.columns = columns
ax = ax.replace(np.nan,0)
plt.figure()
ax.plot(style='o-')
plt.title("Number of references per task using OpenAlex")
# Out:
# Text(0.5, 1.0, 'Number of references per year using OpenAlex for selected datasets')
